-- %% [markdown]
-- # [dbo].[ArticuloDetalle]

-- %%
USE [SISGESAL]
GO

-- %%
/****** Object:  UserDefinedTableType [dbo].[ArticuloDetalle]    Script Date: 05-Nov-24 7:41:20 AM ******/
CREATE TYPE [dbo].[ArticuloDetalle] AS TABLE(
	[CodigoArticulo] [nvarchar](50) NULL,
	[Entrada] [int] NULL,
	[PrecioUnitario] [decimal](18, 2) NULL
)
GO

-- %% [markdown]
-- # [dbo].[TransaccionDetalleTableType]

-- %%
/****** Object:  UserDefinedTableType [dbo].[TransaccionDetalleTableType]    Script Date: 05-Nov-24 7:41:20 AM ******/
CREATE TYPE [dbo].[TransaccionDetalleTableType] AS TABLE(
	[CodigoAlmacen] [int] NULL,
	[CodigoArticulo] [int] NULL,
	[Operacion] [varchar](7) NULL,
	[FechaIngreso] [datetime] NULL,
	[Entrada] [decimal](18, 2) NULL,
	[PrecioUnitario] [decimal](18, 2) NULL
)
GO

-- %% [markdown]
-- # [dbo].[TransaccionDetalleType]

-- %%
/****** Object:  UserDefinedTableType [dbo].[TransaccionDetalleType]    Script Date: 05-Nov-24 7:41:20 AM ******/
CREATE TYPE [dbo].[TransaccionDetalleType] AS TABLE(
	[CodigoAlmacen] [varchar](50) NULL,
	[CodigoArticulo] [int] NULL,
	[Operacion] [varchar](50) NULL,
	[FechaIngreso] [datetime] NULL,
	[Entrada] [int] NULL,
	[PrecioUnitario] [decimal](18, 2) NULL
)
GO

-- %% [markdown]
-- # [dbo].[Almacenes]

-- %%
/****** Object:  Table [dbo].[Almacenes]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Almacenes](
	[Identificador] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [nvarchar](255) NOT NULL,
	[Estado] [bit] NOT NULL,
	[UsuarioCreacion] [nvarchar](255) NULL,
	[FechaCreacion] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Identificador] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Articulos]

-- %%
/****** Object:  Table [dbo].[Articulos]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Articulos](
	[IdentificadorArticulo] [int] IDENTITY(1,1) NOT NULL,
	[CodigoArticulo] [int] NOT NULL,
	[DescripcionArticulo] [nvarchar](255) NULL,
	[TipoArticulo] [nvarchar](255) NULL,
	[PuntoMinimo] [decimal](18, 2) NULL,
	[PuntoMaximo] [decimal](18, 2) NULL,
	[PuntoReorden] [decimal](18, 2) NULL,
	[UsuarioCreacion] [nvarchar](255) NULL,
	[FechaCreacion] [datetime] NULL,
	[Estado] [bit] NOT NULL,
	[codigoAlmacen] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdentificadorArticulo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetRoleClaims]

-- %%
/****** Object:  Table [dbo].[AspNetRoleClaims]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetRoleClaims](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [nvarchar](450) NOT NULL,
	[ClaimType] [nvarchar](max) NULL,
	[ClaimValue] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetRoles]

-- %%
/****** Object:  Table [dbo].[AspNetRoles]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetRoles](
	[Id] [nvarchar](450) NOT NULL,
	[Name] [nvarchar](256) NULL,
	[NormalizedName] [nvarchar](256) NULL,
	[ConcurrencyStamp] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUserClaims]

-- %%
/****** Object:  Table [dbo].[AspNetUserClaims]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUserClaims](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [nvarchar](450) NOT NULL,
	[ClaimType] [nvarchar](max) NULL,
	[ClaimValue] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUserLogins]

-- %%
/****** Object:  Table [dbo].[AspNetUserLogins]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUserLogins](
	[LoginProvider] [nvarchar](128) NOT NULL,
	[ProviderKey] [nvarchar](128) NOT NULL,
	[ProviderDisplayName] [nvarchar](max) NULL,
	[UserId] [nvarchar](450) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[LoginProvider] ASC,
	[ProviderKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUserRoles]

-- %%
/****** Object:  Table [dbo].[AspNetUserRoles]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUserRoles](
	[UserId] [nvarchar](450) NOT NULL,
	[RoleId] [nvarchar](450) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UserId] ASC,
	[RoleId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUsers]

-- %%
/****** Object:  Table [dbo].[AspNetUsers]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUsers](
	[Id] [nvarchar](450) NOT NULL,
	[FirstName] [nvarchar](max) NOT NULL,
	[LastName] [nvarchar](max) NOT NULL,
	[UserName] [nvarchar](256) NULL,
	[NormalizedUserName] [nvarchar](256) NULL,
	[Email] [nvarchar](256) NULL,
	[NormalizedEmail] [nvarchar](256) NULL,
	[EmailConfirmed] [bit] NOT NULL,
	[PasswordHash] [nvarchar](max) NULL,
	[SecurityStamp] [nvarchar](max) NULL,
	[ConcurrencyStamp] [nvarchar](max) NULL,
	[PhoneNumber] [nvarchar](max) NULL,
	[PhoneNumberConfirmed] [bit] NOT NULL,
	[TwoFactorEnabled] [bit] NOT NULL,
	[LockoutEnd] [datetimeoffset](7) NULL,
	[LockoutEnabled] [bit] NOT NULL,
	[AccessFailedCount] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AspNetUserTokens]

-- %%
/****** Object:  Table [dbo].[AspNetUserTokens]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AspNetUserTokens](
	[UserId] [nvarchar](450) NOT NULL,
	[LoginProvider] [nvarchar](128) NOT NULL,
	[Name] [nvarchar](128) NOT NULL,
	[Value] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[UserId] ASC,
	[LoginProvider] ASC,
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConfiguraAlmacenArticulo]

-- %%
/****** Object:  Table [dbo].[ConfiguraAlmacenArticulo]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConfiguraAlmacenArticulo](
	[IdentificadorConfig] [int] IDENTITY(1,1) NOT NULL,
	[IdentificadorAlmacen] [int] NULL,
	[IdentificadorArticulo] [int] NULL,
	[Estado] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdentificadorConfig] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ContadorArticulos]

-- %%
/****** Object:  Table [dbo].[ContadorArticulos]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ContadorArticulos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CodigoAlmacen] [int] NOT NULL,
	[Contador] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ControlIncremental]

-- %%
/****** Object:  Table [dbo].[ControlIncremental]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ControlIncremental](
	[Año] [int] NOT NULL,
	[Numero] [int] NULL,
	[CodigoAlmacen] [varchar](10) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Año] ASC,
	[CodigoAlmacen] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Transaccion]

-- %%
/****** Object:  Table [dbo].[Transaccion]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Transaccion](
	[Ningresos] [nvarchar](20) NOT NULL,
	[CodigoAlmacen] [int] NOT NULL,
	[Nrequisicion] [int] NOT NULL,
	[FechaRequisicion] [datetime] NOT NULL,
	[Operacion] [nvarchar](255) NOT NULL,
	[FechaIngreso] [datetime] NOT NULL,
	[Observacion] [nvarchar](max) NULL,
 CONSTRAINT [PK__Transacc__F5B448F1C07449A4] PRIMARY KEY CLUSTERED 
(
	[Ningresos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TransaccionDetalle]

-- %%
/****** Object:  Table [dbo].[TransaccionDetalle]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TransaccionDetalle](
	[IdentificadorTrans] [int] IDENTITY(1,1) NOT NULL,
	[Ningresos] [nvarchar](20) NOT NULL,
	[CodigoAlmacen] [int] NOT NULL,
	[CodigoArticulo] [int] NULL,
	[Operacion] [nvarchar](255) NOT NULL,
	[FechaIngreso] [datetime] NOT NULL,
	[Entrada] [float] NULL,
	[PrecioUnitario] [decimal](18, 2) NULL,
 CONSTRAINT [PK__Transacc__A691C8D73759A022] PRIMARY KEY CLUSTERED 
(
	[IdentificadorTrans] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__ContadorA__Conta__40F9A68C]

-- %%
ALTER TABLE [dbo].[ContadorArticulos] ADD  DEFAULT ((1)) FOR [Contador]
GO

-- %% [markdown]
-- # [fk_codigoAlmacen]

-- %%
ALTER TABLE [dbo].[Articulos]  WITH CHECK ADD  CONSTRAINT [fk_codigoAlmacen] FOREIGN KEY([codigoAlmacen])
REFERENCES [dbo].[Almacenes] ([Identificador])
GO
ALTER TABLE [dbo].[Articulos] CHECK CONSTRAINT [fk_codigoAlmacen]
GO

-- %% [markdown]
-- # [FK__AspNetRol__RoleI__286302EC]

-- %%
ALTER TABLE [dbo].[AspNetRoleClaims]  WITH CHECK ADD FOREIGN KEY([RoleId])
REFERENCES [dbo].[AspNetRoles] ([Id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__AspNetUse__UserI__2B3F6F97]

-- %%
ALTER TABLE [dbo].[AspNetUserClaims]  WITH CHECK ADD FOREIGN KEY([UserId])
REFERENCES [dbo].[AspNetUsers] ([Id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__AspNetUse__UserI__2E1BDC42]

-- %%
ALTER TABLE [dbo].[AspNetUserLogins]  WITH CHECK ADD FOREIGN KEY([UserId])
REFERENCES [dbo].[AspNetUsers] ([Id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__AspNetUse__RoleI__30F848ED]

-- %%
ALTER TABLE [dbo].[AspNetUserRoles]  WITH CHECK ADD FOREIGN KEY([RoleId])
REFERENCES [dbo].[AspNetRoles] ([Id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__AspNetUse__UserI__31EC6D26]

-- %%
ALTER TABLE [dbo].[AspNetUserRoles]  WITH CHECK ADD FOREIGN KEY([UserId])
REFERENCES [dbo].[AspNetUsers] ([Id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__AspNetUse__UserI__34C8D9D1]

-- %%
ALTER TABLE [dbo].[AspNetUserTokens]  WITH CHECK ADD FOREIGN KEY([UserId])
REFERENCES [dbo].[AspNetUsers] ([Id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Configura__Ident__571DF1D5]

-- %%
ALTER TABLE [dbo].[ConfiguraAlmacenArticulo]  WITH CHECK ADD FOREIGN KEY([IdentificadorAlmacen])
REFERENCES [dbo].[Almacenes] ([Identificador])
GO

-- %% [markdown]
-- # [FK__Configura__Ident__5812160E]

-- %%
ALTER TABLE [dbo].[ConfiguraAlmacenArticulo]  WITH CHECK ADD FOREIGN KEY([IdentificadorArticulo])
REFERENCES [dbo].[Articulos] ([IdentificadorArticulo])
GO

-- %% [markdown]
-- # [FK__ContadorA__Codig__41EDCAC5]

-- %%
ALTER TABLE [dbo].[ContadorArticulos]  WITH CHECK ADD FOREIGN KEY([CodigoAlmacen])
REFERENCES [dbo].[Almacenes] ([Identificador])
GO

-- %% [markdown]
-- # [FK__Transacci__Codig__403A8C7D]

-- %%
ALTER TABLE [dbo].[Transaccion]  WITH NOCHECK ADD  CONSTRAINT [FK__Transacci__Codig__403A8C7D] FOREIGN KEY([CodigoAlmacen])
REFERENCES [dbo].[Almacenes] ([Identificador])
GO
ALTER TABLE [dbo].[Transaccion] CHECK CONSTRAINT [FK__Transacci__Codig__403A8C7D]
GO

-- %% [markdown]
-- # [FK__Transacci__Codig__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[TransaccionDetalle]  WITH CHECK ADD  CONSTRAINT [FK__Transacci__Codig__5BE2A6F2] FOREIGN KEY([CodigoAlmacen])
REFERENCES [dbo].[Almacenes] ([Identificador])
GO
ALTER TABLE [dbo].[TransaccionDetalle] CHECK CONSTRAINT [FK__Transacci__Codig__5BE2A6F2]
GO

-- %% [markdown]
-- # [FK__Transacci__Codig__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[TransaccionDetalle]  WITH CHECK ADD  CONSTRAINT [FK__Transacci__Codig__5CD6CB2B] FOREIGN KEY([CodigoArticulo])
REFERENCES [dbo].[Articulos] ([IdentificadorArticulo])
GO
ALTER TABLE [dbo].[TransaccionDetalle] CHECK CONSTRAINT [FK__Transacci__Codig__5CD6CB2B]
GO

-- %% [markdown]
-- # [FK__Transacci__Ningr__5DCAEF64]

-- %%
ALTER TABLE [dbo].[TransaccionDetalle]  WITH CHECK ADD  CONSTRAINT [FK__Transacci__Ningr__5DCAEF64] FOREIGN KEY([Ningresos])
REFERENCES [dbo].[Transaccion] ([Ningresos])
GO
ALTER TABLE [dbo].[TransaccionDetalle] CHECK CONSTRAINT [FK__Transacci__Ningr__5DCAEF64]
GO

-- %% [markdown]
-- # [CHK_Estado]

-- %%
ALTER TABLE [dbo].[Almacenes]  WITH CHECK ADD  CONSTRAINT [CHK_Estado] CHECK  (([Estado]=(1) OR [Estado]=(0)))
GO
ALTER TABLE [dbo].[Almacenes] CHECK CONSTRAINT [CHK_Estado]
GO

-- %% [markdown]
-- # [dbo].[GenerarCodigo]

-- %%
/****** Object:  StoredProcedure [dbo].[GenerarCodigo]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 CREATE PROCEDURE [dbo].[GenerarCodigo]
    @CodigoAlmacen VARCHAR(10),
    @NuevoCodigo VARCHAR(50) OUTPUT
AS
BEGIN
    DECLARE @AñoActual INT = YEAR(GETDATE());
    DECLARE @NumeroIncremental INT;

    -- Verificar si ya hay registros para el año actual y el código de almacén
    IF EXISTS (SELECT 1 FROM ControlIncremental WHERE Año = @AñoActual AND CodigoAlmacen = @CodigoAlmacen)
    BEGIN
        -- Obtener el último número para el año actual y el almacén específico
        SELECT @NumeroIncremental = Numero + 1 
        FROM ControlIncremental 
        WHERE Año = @AñoActual AND CodigoAlmacen = @CodigoAlmacen;

        -- Actualizar el número
        UPDATE ControlIncremental
        SET Numero = @NumeroIncremental
        WHERE Año = @AñoActual AND CodigoAlmacen = @CodigoAlmacen;
    END
    ELSE
    BEGIN
        -- Si es el primer registro del año para este almacén, inicializar el número
        SET @NumeroIncremental = 1;

        -- Insertar el nuevo registro en la tabla de control
        INSERT INTO ControlIncremental (Año, Numero, CodigoAlmacen)
        VALUES (@AñoActual, @NumeroIncremental, @CodigoAlmacen);
    END

    -- Generar el código en el formato deseado: "Incremental-Numero-Año-CodigoAlmacen"
    SET @NuevoCodigo = CAST(@NumeroIncremental AS VARCHAR(10)) + '-'
                      + RIGHT('0000' + CAST(@NumeroIncremental AS VARCHAR(10)), 4) + '-'
                      + CAST(@AñoActual AS VARCHAR(4)) + '-'
                      + @CodigoAlmacen;
END;
GO

-- %% [markdown]
-- # [dbo].[ObtenerProximoNumeroRequisicion]

-- %%
/****** Object:  StoredProcedure [dbo].[ObtenerProximoNumeroRequisicion]    Script Date: 05-Nov-24 7:41:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ObtenerProximoNumeroRequisicion]
    @NuevoNumero INT OUTPUT
AS
BEGIN
    SET NOCOUNT ON;

    BEGIN TRY
        BEGIN TRANSACTION;

        -- Obtener el último número de requisición usado
        DECLARE @UltimoNumero INT;

        SELECT @UltimoNumero = ISNULL(MAX(CAST(Nrequisicion AS INT)), 0)
        FROM Transaccion WITH (UPDLOCK, HOLDLOCK); -- Bloquear la tabla para evitar lecturas sucias

        -- Incrementar el número de requisición
        SET @NuevoNumero = @UltimoNumero + 1;

        -- Confirmar la transacción si todo está correcto
        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        -- Si ocurre algún error, se hace rollback de la transacción
        IF @@TRANCOUNT > 0
        BEGIN
            ROLLBACK TRANSACTION;
        END

        -- Usar RAISERROR en lugar de THROW para versiones anteriores a SQL Server 2012
        DECLARE @ErrorMessage NVARCHAR(4000), @ErrorSeverity INT, @ErrorState INT;
        SELECT @ErrorMessage = ERROR_MESSAGE(), @ErrorSeverity = ERROR_SEVERITY(), @ErrorState = ERROR_STATE();
        RAISERROR (@ErrorMessage, @ErrorSeverity, @ErrorState);
    END CATCH
END;
GO
